# %% [markdown]
# <a href="https://colab.research.google.com/github/regina-fonseca-avila/data_science/blob/main/kmeans/como_funciona.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # K-means
# ## Como funciona

# %%
# conjunto de  pontos para exemplo
x = [1,2,3.4,4.5,9,10,11,12,15,15.5,16,17]
y = list(np.zeros(12))

# %% [markdown]
# ## Quero agrupar um conjunto de dados em 3 clusters

# %%
plt.figure(figsize=(20,10))
plt.scatter(x, y, c = 'grey', s = 250, zorder = 2)
plt.ylim(-0.2,0.3)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

# %% [markdown]
# ## Intuitivamente podemos agrupá-los assim

# %%
plt.figure(figsize=(20,10))
plt.scatter(x[0:4], y[0:4], c = 'blue', s = 250, zorder = 2)
plt.scatter(x[4:8], y[4:8], c = 'green', s = 250, zorder = 2)
plt.scatter(x[8:12], y[8:12], c = 'orange', s = 250, zorder = 2)
plt.ylim(-0.2,0.3)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

# %% [markdown]
# ## E usando o K-means?
#
# ### 1. Escolho número de clusters: K = 3
#
# ### 2. Escolho aleatoriamente 3 pontos
#
# Esses pontos serão os centroides dos cluster

# %%
plt.figure(figsize=(20,10))
plt.scatter(x, y, c = 'grey', s = 250, zorder = 2)
plt.scatter(x[1], y[1], c = 'blue', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[3], y[3], c = 'green', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[6], y[6], c = 'orange', s = 1250, marker = 'X', zorder = 2)
plt.ylim(-0.2,0.3)
plt.axhline(c = 'black', zorder = 1)
plt.xticks([]);
plt.yticks([]);
plt.annotate('', xy = (2,0.03), xytext = (3,0.23),arrowprops=dict(facecolor='black'))
plt.annotate('', xy = (4.5,0.03), xytext = (3,0.23),arrowprops=dict(facecolor='black'))
plt.annotate('', xy = (11,0.03), xytext = (3,0.23),arrowprops=dict(facecolor='black'))
plt.axis('off');
plt.text(3, 0.25, 'Estes são os centroides',
         {'color': 'k', 'fontsize': 24, 'ha': 'center', 'va': 'center'});

# %% [markdown]
# ### 3. Distância do primeiro ponto aos três centroides iniciais

# %%
plt.figure(figsize=(20,10))
plt.scatter(x, y, c = 'grey', s = 250, zorder = 2)
plt.scatter(x[1], y[1], c = 'blue', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[3], y[3], c = 'green', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[6], y[6], c = 'orange', s = 1250, marker = 'X', zorder = 2)
plt.ylim(-0.2,0.3)
plt.xlim(0,18)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

plt.hlines(y=.1, xmin=x[0], xmax=x[1],linewidth=8, color='blue')
plt.hlines(y=.15, xmin=x[0], xmax=x[3],linewidth=8, color='green')
plt.hlines(y=.20, xmin=x[0], xmax=x[6],linewidth=8, color='orange');

# %% [markdown]
# - as linhas coloridas representam a distância até o centro do cluster, representado pelo simbolo X da mesma cor.

# %% [markdown]
# ### 4. Associar o primeiro ponto ao cluster mais próximo
#
# Menor distância até o centroide

# %%
plt.figure(figsize=(20,10))
plt.scatter(x, y, c = 'grey', s = 250, zorder = 2)
plt.scatter(x[1], y[1], c = 'blue', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[3], y[3], c = 'green', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[6], y[6], c = 'orange', s = 1250, marker = 'X', zorder = 2)
plt.ylim(-0.2,0.3)
plt.xlim(0,18)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

# associando primeiro ponto ao cluster azul
plt.scatter(x[0], y[0], c = 'blue', s = 250, zorder = 2);

# %% [markdown]
# ### 5. Fazer a mesma coisa para o próximo ponto (Medir a distância aos clusters)
#
# Vamos usar o terceiro ponto, porque o segundo foi escolhido como centroide e já está no cluster azul

# %%
plt.figure(figsize=(20,10))
plt.scatter(x, y, c = 'grey', s = 250, zorder = 2)
plt.scatter(x[1], y[1], c = 'blue', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[3], y[3], c = 'green', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[6], y[6], c = 'orange', s = 1250, marker = 'X', zorder = 2)
plt.ylim(-0.2,0.3)
plt.xlim(0,18)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

# associando primeiro ponto ao cluster azul
plt.scatter(x[0], y[0], c = 'blue', s = 250, zorder = 2)

plt.hlines(y=.1, xmin=x[2], xmax=x[1],linewidth=8, color='blue')
plt.hlines(y=.15, xmin=x[2], xmax=x[3],linewidth=8, color='green')
plt.hlines(y=.20, xmin=x[2], xmax=x[6],linewidth=8, color='orange');

# %% [markdown]
# ### 6. Associar o terceiro ponto ao cluster mais próximo
#
# Menor distância até o centroide

# %%
plt.figure(figsize=(20,10))
plt.scatter(x, y, c = 'grey', s = 250, zorder = 2)
plt.scatter(x[1], y[1], c = 'blue', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[3], y[3], c = 'green', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[6], y[6], c = 'orange', s = 1250, marker = 'X', zorder = 2)
plt.ylim(-0.2,0.3)
plt.xlim(0,18)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');


# associando primeiro ponto ao cluster azul
plt.scatter(x[0], y[0], c = 'blue', s = 250, zorder = 2)
# associando terceiro ponto ao cluster verde
plt.scatter(x[2], y[2], c = 'green', s = 250, zorder = 2);

# %% [markdown]
# ### 7. Fazer o mesmo para o próximo ponto (Medir a distância aos clusters)

# %%
plt.figure(figsize=(20,10))
plt.scatter(x, y, c = 'grey', s = 250, zorder = 2)
plt.scatter(x[1], y[1], c = 'blue', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[3], y[3], c = 'green', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[6], y[6], c = 'orange', s = 1250, marker = 'X', zorder = 2)
plt.ylim(-0.2,0.3)
plt.xlim(0,18)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

# associando primeiro ponto ao cluster azul
plt.scatter(x[0], y[0], c = 'blue', s = 250, zorder = 2)
# associando terceiro ponto ao cluster azul
plt.scatter(x[2], y[2], c = 'green', s = 250, zorder = 2)

plt.hlines(y=.1, xmin=x[4], xmax=x[1],linewidth=8, color='blue')
plt.hlines(y=.15, xmin=x[4], xmax=x[3],linewidth=8, color='green')
plt.hlines(y=.20, xmin=x[4], xmax=x[6],linewidth=8, color='orange');

# %% [markdown]
# ### 8. Associar ao cluster mais próximo

# %%
plt.figure(figsize=(20,10))
plt.scatter(x, y, c = 'grey', s = 250, zorder = 2)
plt.scatter(x[1], y[1], c = 'blue', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[3], y[3], c = 'green', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[6], y[6], c = 'orange', s = 1250, marker = 'X', zorder = 2)
plt.ylim(-0.2,0.3)
plt.xlim(0,18)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

# associando primeiro ponto ao cluster azul
plt.scatter(x[0], y[0], c = 'blue', s = 250, zorder = 2)
# associando terceiro ponto ao cluster azul
plt.scatter(x[2], y[2], c = 'green', s = 250, zorder = 2)
# associando o quinto ponto ao cluster laranja
plt.scatter(x[4], y[4], c = 'orange', s = 250, zorder = 2);

# %% [markdown]
# ### 9. O resto dos pontos  estão mais próximos ao centroide laranja e vão ser associados a ele

# %%
plt.figure(figsize=(20,10))
plt.scatter(x, y, c = 'grey', s = 250, zorder = 2)
plt.scatter(x[1], y[1], c = 'blue', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[3], y[3], c = 'green', s = 1250, marker = 'X', zorder = 2)
plt.scatter(x[6], y[6], c = 'orange', s = 1250, marker = 'X', zorder = 2)
plt.ylim(-0.2,0.3)
plt.xlim(0,18)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

# associando primeiro ponto ao cluster azul
plt.scatter(x[0], y[0], c = 'blue', s = 250, zorder = 2)
# associando terceiro ponto ao cluster azul
plt.scatter(x[2], y[2], c = 'green', s = 250, zorder = 2)
# associando o quinto ponto ao cluster laranja
plt.scatter(x[4:12], y[4:12], c = 'orange', s = 250, zorder = 2);

# %% [markdown]
# ### 10. Calcula os novos centroides (média)
#
# - É a média dos pontos do cluster

# %%
# cálculo centroide
c_blue = np.mean(x[0:2])
c_green = np.mean(x[2:4])
c_orange = np.mean(x[4:12])

# %%
plt.figure(figsize=(20,10))
# centroides
plt.scatter(c_blue, y[1], c = 'blue', s = 1250, marker = 'X', zorder = 2)
plt.scatter(c_green, y[3], c = 'green', s = 1250, marker = 'X', zorder = 2)
plt.scatter(c_orange, y[6], c = 'orange', s = 1250, marker = 'X', zorder = 2)
plt.ylim(-0.2,0.3)
plt.xlim(0,18)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

# pontos cluster azul
plt.scatter(x[0:2], y[0:2], c = 'blue', s = 250, zorder = 2)
# pontos cluster verde
plt.scatter(x[2:4], y[2:4], c = 'green', s = 250, zorder = 2)
# pontos cluster laranja
plt.scatter(x[4:12], y[4:12], c = 'orange', s = 250, zorder = 2)


plt.annotate('', xy = (c_blue,0.03), xytext = (3,0.23),arrowprops=dict(facecolor='black'))
plt.annotate('', xy = (c_green,0.03), xytext = (3,0.23),arrowprops=dict(facecolor='black'))
plt.annotate('', xy = (c_orange,0.03), xytext = (3,0.23),arrowprops=dict(facecolor='black'))

plt.text(3, 0.25, 'Novos centroides',
         {'color': 'k', 'fontsize': 24, 'ha': 'center', 'va': 'center'});

# %% [markdown]
# ### 11. Repetimos os passos anteriores
#
# - Medir a distância de cada ponto aos centroides
# - Associar o ponto ao cluster (centroide) mais próximo
#
# #### Primeiro ponto

# %%
plt.figure(figsize=(20,10))
# centroides
plt.scatter(c_blue, y[1], c = 'blue', s = 1250, marker = 'X', zorder = 2)
plt.scatter(c_green, y[3], c = 'green', s = 1250, marker = 'X', zorder = 2)
plt.scatter(c_orange, y[6], c = 'orange', s = 1250, marker = 'X', zorder = 2)
plt.ylim(-0.2,0.3)
plt.xlim(0,18)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

# pontos cluster azul
plt.scatter(x[0:2], y[0:2], c = 'blue', s = 250, zorder = 2)
# pontos cluster verde
plt.scatter(x[2:4], y[2:4], c = 'green', s = 250, zorder = 2)
# pontos cluster laranja
plt.scatter(x[4:12], y[4:12], c = 'orange', s = 250, zorder = 2)

plt.hlines(y=.1, xmin=x[0], xmax=c_blue,linewidth=8, color='blue')
plt.hlines(y=.15, xmin=x[0], xmax=c_green,linewidth=8, color='green')
plt.hlines(y=.20, xmin=x[0], xmax=c_orange,linewidth=8, color='orange')


plt.annotate('', xy = (x[0],-0.025), xytext = (3,-0.13),arrowprops=dict(facecolor='black'))

plt.text(3, -0.15, 'Não muda de cluster',
         {'color': 'k', 'fontsize': 24, 'ha': 'center', 'va': 'center'});

# %% [markdown]
# ### 12. Segundo ponto

# %%
plt.figure(figsize=(20,10))
# centroides
plt.scatter(c_blue, y[1], c = 'blue', s = 1250, marker = 'X', zorder = 2)
plt.scatter(c_green, y[3], c = 'green', s = 1250, marker = 'X', zorder = 2)
plt.scatter(c_orange, y[6], c = 'orange', s = 1250, marker = 'X', zorder = 2)
plt.ylim(-0.2,0.3)
plt.xlim(0,18)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

# pontos cluster azul
plt.scatter(x[0:2], y[0:2], c = 'blue', s = 250, zorder = 2)
# pontos cluster verde
plt.scatter(x[2:4], y[2:4], c = 'green', s = 250, zorder = 2)
# pontos cluster laranja
plt.scatter(x[4:12], y[4:12], c = 'orange', s = 250, zorder = 2)

plt.hlines(y=.1, xmin=x[1], xmax=c_blue,linewidth=8, color='blue')
plt.hlines(y=.15, xmin=x[1], xmax=c_green,linewidth=8, color='green')
plt.hlines(y=.20, xmin=x[1], xmax=c_orange,linewidth=8, color='orange')


plt.annotate('', xy = (x[1],-0.025), xytext = (3,-0.13),arrowprops=dict(facecolor='black'))

plt.text(3, -0.15, 'Não muda de cluster',
         {'color': 'k', 'fontsize': 24, 'ha': 'center', 'va': 'center'});

# %% [markdown]
# ### 13. Terceiro ponto

# %%
plt.figure(figsize=(20,10))
# centroides
plt.scatter(c_blue, y[1], c = 'blue', s = 1250, marker = 'X', zorder = 2)
plt.scatter(c_green, y[3], c = 'green', s = 1250, marker = 'X', zorder = 2)
plt.scatter(c_orange, y[6], c = 'orange', s = 1250, marker = 'X', zorder = 2)
plt.ylim(-0.2,0.3)
plt.xlim(0,18)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

# pontos cluster azul
plt.scatter(x[0:2], y[0:2], c = 'blue', s = 250, zorder = 2)
# pontos cluster verde
plt.scatter(x[2:4], y[2:4], c = 'green', s = 250, zorder = 2)
# pontos cluster laranja
plt.scatter(x[4:12], y[4:12], c = 'orange', s = 250, zorder = 2)

plt.hlines(y=.1, xmin=x[2], xmax=c_blue,linewidth=8, color='blue')
plt.hlines(y=.15, xmin=x[2], xmax=c_green,linewidth=8, color='green')
plt.hlines(y=.20, xmin=x[2], xmax=c_orange,linewidth=8, color='orange')


plt.annotate('', xy = (x[2],-0.025), xytext = (3,-0.13),arrowprops=dict(facecolor='black'))

plt.text(3, -0.15, 'Não muda de cluster',
         {'color': 'k', 'fontsize': 24, 'ha': 'center', 'va': 'center'});

# %% [markdown]
# ### 14. Quarto ponto

# %%
plt.figure(figsize=(20,10))
# centroides
plt.scatter(c_blue, y[1], c = 'blue', s = 1250, marker = 'X', zorder = 2)
plt.scatter(c_green, y[3], c = 'green', s = 1250, marker = 'X', zorder = 2)
plt.scatter(c_orange, y[6], c = 'orange', s = 1250, marker = 'X', zorder = 2)
plt.ylim(-0.2,0.3)
plt.xlim(0,18)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

# pontos cluster azul
plt.scatter(x[0:2], y[0:2], c = 'blue', s = 250, zorder = 2)
# pontos cluster verde
plt.scatter(x[2:4], y[2:4], c = 'green', s = 250, zorder = 2)
# pontos cluster laranja
plt.scatter(x[4:12], y[4:12], c = 'orange', s = 250, zorder = 2)

plt.hlines(y=.1, xmin=x[3], xmax=c_blue,linewidth=8, color='blue')
plt.hlines(y=.15, xmin=x[3], xmax=c_green,linewidth=8, color='green')
plt.hlines(y=.20, xmin=x[3], xmax=c_orange,linewidth=8, color='orange')


plt.annotate('', xy = (x[3],-0.025), xytext = (3,-0.13),arrowprops=dict(facecolor='black'))

plt.text(3, -0.15, 'Não muda de cluster',
         {'color': 'k', 'fontsize': 24, 'ha': 'center', 'va': 'center'});

# %% [markdown]
# ### 15. Quinto ao décimo primeiro pontos

# %%
plt.figure(figsize=(20,10))
# centroides
plt.scatter(c_blue, y[1], c = 'blue', s = 1250, marker = 'X', zorder = 2)
plt.scatter(c_green, y[3], c = 'green', s = 1250, marker = 'X', zorder = 2)
plt.scatter(c_orange, y[6], c = 'orange', s = 1250, marker = 'X', zorder = 2)
plt.ylim(-0.2,0.3)
plt.xlim(0,18)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

# pontos cluster azul
plt.scatter(x[0:2], y[0:2], c = 'blue', s = 250, zorder = 2)
# pontos cluster verde
plt.scatter(x[2:4], y[2:4], c = 'green', s = 250, zorder = 2)
# pontos cluster laranja
plt.scatter(x[4:12], y[4:12], c = 'orange', s = 250, zorder = 2)

plt.hlines(y=.1, xmin=x[4], xmax=c_blue,linewidth=8, color='blue')
plt.hlines(y=.15, xmin=x[4], xmax=c_green,linewidth=8, color='green')
plt.hlines(y=.20, xmin=x[4], xmax=c_orange,linewidth=8, color='orange')


plt.annotate('', xy = (x[4],-0.025), xytext = (3,-0.13),arrowprops=dict(facecolor='black'))

plt.text(3, -0.15, 'Não muda de cluster',
         {'color': 'k', 'fontsize': 24, 'ha': 'center', 'va': 'center'});

# %% [markdown]
# ### 16. Chegamos ao final
#
# - Nenhum ponto mudou de cluster
# - Os centroides continuam os mesmos

# %%
plt.figure(figsize=(20,10))

plt.ylim(-0.2,0.3)
plt.xlim(0,18)
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

# pontos cluster azul
plt.scatter(x[0:2], y[0:2], c = 'blue', s = 250, zorder = 2)
# pontos cluster verde
plt.scatter(x[2:4], y[2:4], c = 'green', s = 250, zorder = 2)
# pontos cluster laranja
plt.scatter(x[4:12], y[4:12], c = 'orange', s = 250, zorder = 2);

# %% [markdown]
# - Resultado diferente do que dividimos intuitivamente no olho.
#
# - Esse método depende dos centroides iniciais.
#
# - O algoritmo do sklearn trata esse ponto inicializando o método mais de uma vez com centroies diferentes e tem um critério para estabelecer qual o melhor resultado obtido
#
# - Vamos fazer a clusterização usando o sklearn

# %% [markdown]
# ## 1. Número de clusters k = 3, seleção dos centros pelo sklearn
#
# - Usando o parâmetro ```init = 'k-means++’``` que seleciona o centro dos clusters de froma a acelerar a convergencia.

# %%
from sklearn.cluster import KMeans

random_state = 42
X = pd.DataFrame(x)


y_pred = KMeans(n_clusters=3,n_init=10,
                random_state=random_state).fit_predict(X)


plt.figure(figsize=(20, 10))
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

colors = np.array(['orange', 'blue', 'green']);

plt.scatter(x, y, color = colors[y_pred], s = 250, zorder = 2);

# %% [markdown]
# - Cluster encontrados como esperado, da mesma forma que dividimos intuitivamento no início

# %% [markdown]
# ## 2. Número de clusters k = 3, escolhemos o centro dos clusters
#
# - Usando o parâmetro init = um array com os centros

# %%
X = pd.DataFrame(x)

centro= np.array([[2],[4.5],[11]])


y_pred = KMeans(n_clusters=3,n_init=10, init = centro,
                random_state=random_state).fit_predict(X);


plt.figure(figsize=(20, 10))
plt.axhline(c = 'black', zorder = 1)
plt.axis('off');

colors = np.array(['orange', 'blue', 'green'])


plt.scatter(x, y, color = colors[y_pred], s = 250, zorder = 2);
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py:1146: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)

# %% [markdown]
# - resultado diferente do anterior
#
# - é igual ao que fizemos manualmente
#
# - veja a mensagem que executou o Kmeans apenas uma vez

# %% [markdown]
# ## Comentários
#
# A referência [1] também ilustra o caso de duas dimensões e mostra como são calculadas as distâncias quando temos n dimensões, ou seja, quando incluímos n variávies para encontrar os clusters.

# %% [markdown]
# ## Referências
#
# [1] https://www.youtube.com/watch?v=4b5d3muPQmA&t=171s
#
# [2] https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html
