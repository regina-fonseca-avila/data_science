# %% [markdown]
# <a href="https://colab.research.google.com/github/regina-fonseca-avila/data_science/blob/main/table_visualization_pandas/table_visualization_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# # **VISUALIZAÇÃO DE TABELAS PANDAS**
#
# As vezes precisamos de fazer uma apresentação rápida e aqui mostramos como deixar suas tabelas bonitas e formas de destacar informações importantes em uma análise mesmo quando está utilizando um notebook.
#
# Vamos nos basear em duas referências
#
# [1] https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html
#
# [2] https://towardsdatascience.com/style-pandas-dataframe-like-a-master-6b02bf6468b0
#
# para ver como utilizar o Styler Class e trazer alguns exemplos.
#
# - Styler cria uma tabela HTML e aproveita a linguagem CSS pra manipular parâmetros como
#
#   - cor, font, borda, fundo
#
# Styling deve ser utilizado depois do dados no DataFrame serem processados
#
# É ideal para ser utilizadas nas tabelas (dataframes) pequenos que já trazem dados consolidados.
#
# As duas referências trazem exemplos muito fáceis de serem compreendidos. Para ver como se **formata valores** veja a referência [2].
#
# Vamos trazer um exemplo utilizando um dataset público, faremos um groupby para mostrar os dados de vendas consolidado por hora e por dia da semana e vamos mostrar como utilizando o style podemos destacar informações imprtantes dos dados de forma muito simples.

# %% [markdown]
# # Dados
#
# **UCI machine learning repository**
#
# Online Retail Data Set
#
# Mais informações [aqui](https://archive.ics.uci.edu/ml/datasets/online+retail#).

# %%
# read data and first lines
file_path = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx'
            
online = pd.read_excel(file_path)

online.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
online.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# cleaning dataset
online = online[online.UnitPrice > 0]
online = online[online.Quantity > 0]
online = online[~online.CustomerID.isna()]

# %% [markdown]
# ## Criando colunas de dia da semana e hora da compra

# %%
# The day of the week with Monday=0, Sunday=6
online['DayOfWeek'] = online['InvoiceDate'].dt.weekday

# The hours of the datetime
online['Hour'] = online['InvoiceDate'].dt.hour

online.head(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#   InvoiceNo StockCode  ... DayOfWeek  Hour
# 0    536365    85123A  ...         2     8
# 1    536365     71053  ...         2     8
# 2    536365    84406B  ...         2     8
#
# [3 rows x 10 columns]

# %% [markdown]
# # Número de compra únicas por hora e dia da semana

# %%
n_tickets_by_week_and_hour = online.groupby(['DayOfWeek','Hour'], as_index=False).agg({'InvoiceNo':'nunique'})
n_tickets_by_week_and_hour.head()
# Out:
#    DayOfWeek  Hour  InvoiceNo
# 0          0     7          4
# 1          0     8         85
# 2          0     9        251
# 3          0    10        322
# 4          0    11        340

# %%
unique_tickets_by_week_and_hour = pd.pivot_table(n_tickets_by_week_and_hour, 
                                          index = 'DayOfWeek',
                                          columns = 'Hour', 
                                          values = 'InvoiceNo',
                                          fill_value=0)

unique_tickets_by_week_and_hour
# Out:
# Hour       6   7    8    9    10   11   12  ...   14   15   16   17   18   19  20
# DayOfWeek                                   ...
# 0           0   4   85  251  322  340  480  ...  374  317  184   70    0    0   0
# 1           0   5  115  290  393  405  531  ...  371  345  163   88    3    0   0
# 2           0   5  116  290  434  413  611  ...  417  371  223   79    0    2   1
# 3           1   9  119  294  442  370  586  ...  445  421  309  245  164  133  16
# 4           0   6  120  266  410  364  463  ...  361  253  115   62    2    9   1
# 6           0   0    0    2  225  385  459  ...  306  330  106    0    0    0   0
#
# [6 rows x 15 columns]

# %% [markdown]
# # Estilo da Tabela

# %%
s = unique_tickets_by_week_and_hour.style

cell_hover = { # for row hover use <tr> instead of <td>
    'selector': 'td:hover',
    'props': [('background-color', '#ffffb3')]
}
index_names = {
    'selector': '.index_name',
    'props': 'font-style: italic; color: darkgrey; font-weight:normal;'
}
headers = {
    'selector': 'th:not(.index_name)',
    'props': 'background-color: #000076; color: white;'
}
s.set_table_styles([cell_hover, index_names, headers])
# Out:
# <style type="text/css">
# #T_7ce66_ td:hover {
#   background-color: #ffffb3;
# }
# #T_7ce66_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_7ce66_ th:not(.index_name) {
#   background-color: #000076;
#   color: white;
# }
# </style>
# <table id="T_7ce66_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Hour</th>
#       <th class="col_heading level0 col0" >6</th>
#       <th class="col_heading level0 col1" >7</th>
#       <th class="col_heading level0 col2" >8</th>
#       <th class="col_heading level0 col3" >9</th>
#       <th class="col_heading level0 col4" >10</th>
#       <th class="col_heading level0 col5" >11</th>
#       <th class="col_heading level0 col6" >12</th>
#       <th class="col_heading level0 col7" >13</th>
#       <th class="col_heading level0 col8" >14</th>
#       <th class="col_heading level0 col9" >15</th>
#       <th class="col_heading level0 col10" >16</th>
#       <th class="col_heading level0 col11" >17</th>
#       <th class="col_heading level0 col12" >18</th>
#       <th class="col_heading level0 col13" >19</th>
#       <th class="col_heading level0 col14" >20</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DayOfWeek</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ce66_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ce66_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_7ce66_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_7ce66_row0_col2" class="data row0 col2" >85</td>
#       <td id="T_7ce66_row0_col3" class="data row0 col3" >251</td>
#       <td id="T_7ce66_row0_col4" class="data row0 col4" >322</td>
#       <td id="T_7ce66_row0_col5" class="data row0 col5" >340</td>
#       <td id="T_7ce66_row0_col6" class="data row0 col6" >480</td>
#       <td id="T_7ce66_row0_col7" class="data row0 col7" >436</td>
#       <td id="T_7ce66_row0_col8" class="data row0 col8" >374</td>
#       <td id="T_7ce66_row0_col9" class="data row0 col9" >317</td>
#       <td id="T_7ce66_row0_col10" class="data row0 col10" >184</td>
#       <td id="T_7ce66_row0_col11" class="data row0 col11" >70</td>
#       <td id="T_7ce66_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_7ce66_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_7ce66_row0_col14" class="data row0 col14" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7ce66_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7ce66_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_7ce66_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_7ce66_row1_col2" class="data row1 col2" >115</td>
#       <td id="T_7ce66_row1_col3" class="data row1 col3" >290</td>
#       <td id="T_7ce66_row1_col4" class="data row1 col4" >393</td>
#       <td id="T_7ce66_row1_col5" class="data row1 col5" >405</td>
#       <td id="T_7ce66_row1_col6" class="data row1 col6" >531</td>
#       <td id="T_7ce66_row1_col7" class="data row1 col7" >475</td>
#       <td id="T_7ce66_row1_col8" class="data row1 col8" >371</td>
#       <td id="T_7ce66_row1_col9" class="data row1 col9" >345</td>
#       <td id="T_7ce66_row1_col10" class="data row1 col10" >163</td>
#       <td id="T_7ce66_row1_col11" class="data row1 col11" >88</td>
#       <td id="T_7ce66_row1_col12" class="data row1 col12" >3</td>
#       <td id="T_7ce66_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_7ce66_row1_col14" class="data row1 col14" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7ce66_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7ce66_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_7ce66_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_7ce66_row2_col2" class="data row2 col2" >116</td>
#       <td id="T_7ce66_row2_col3" class="data row2 col3" >290</td>
#       <td id="T_7ce66_row2_col4" class="data row2 col4" >434</td>
#       <td id="T_7ce66_row2_col5" class="data row2 col5" >413</td>
#       <td id="T_7ce66_row2_col6" class="data row2 col6" >611</td>
#       <td id="T_7ce66_row2_col7" class="data row2 col7" >493</td>
#       <td id="T_7ce66_row2_col8" class="data row2 col8" >417</td>
#       <td id="T_7ce66_row2_col9" class="data row2 col9" >371</td>
#       <td id="T_7ce66_row2_col10" class="data row2 col10" >223</td>
#       <td id="T_7ce66_row2_col11" class="data row2 col11" >79</td>
#       <td id="T_7ce66_row2_col12" class="data row2 col12" >0</td>
#       <td id="T_7ce66_row2_col13" class="data row2 col13" >2</td>
#       <td id="T_7ce66_row2_col14" class="data row2 col14" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7ce66_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7ce66_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_7ce66_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_7ce66_row3_col2" class="data row3 col2" >119</td>
#       <td id="T_7ce66_row3_col3" class="data row3 col3" >294</td>
#       <td id="T_7ce66_row3_col4" class="data row3 col4" >442</td>
#       <td id="T_7ce66_row3_col5" class="data row3 col5" >370</td>
#       <td id="T_7ce66_row3_col6" class="data row3 col6" >586</td>
#       <td id="T_7ce66_row3_col7" class="data row3 col7" >479</td>
#       <td id="T_7ce66_row3_col8" class="data row3 col8" >445</td>
#       <td id="T_7ce66_row3_col9" class="data row3 col9" >421</td>
#       <td id="T_7ce66_row3_col10" class="data row3 col10" >309</td>
#       <td id="T_7ce66_row3_col11" class="data row3 col11" >245</td>
#       <td id="T_7ce66_row3_col12" class="data row3 col12" >164</td>
#       <td id="T_7ce66_row3_col13" class="data row3 col13" >133</td>
#       <td id="T_7ce66_row3_col14" class="data row3 col14" >16</td>
#     </tr>
#     <tr>
#       <th id="T_7ce66_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7ce66_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_7ce66_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_7ce66_row4_col2" class="data row4 col2" >120</td>
#       <td id="T_7ce66_row4_col3" class="data row4 col3" >266</td>
#       <td id="T_7ce66_row4_col4" class="data row4 col4" >410</td>
#       <td id="T_7ce66_row4_col5" class="data row4 col5" >364</td>
#       <td id="T_7ce66_row4_col6" class="data row4 col6" >463</td>
#       <td id="T_7ce66_row4_col7" class="data row4 col7" >397</td>
#       <td id="T_7ce66_row4_col8" class="data row4 col8" >361</td>
#       <td id="T_7ce66_row4_col9" class="data row4 col9" >253</td>
#       <td id="T_7ce66_row4_col10" class="data row4 col10" >115</td>
#       <td id="T_7ce66_row4_col11" class="data row4 col11" >62</td>
#       <td id="T_7ce66_row4_col12" class="data row4 col12" >2</td>
#       <td id="T_7ce66_row4_col13" class="data row4 col13" >9</td>
#       <td id="T_7ce66_row4_col14" class="data row4 col14" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7ce66_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_7ce66_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_7ce66_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_7ce66_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_7ce66_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_7ce66_row5_col4" class="data row5 col4" >225</td>
#       <td id="T_7ce66_row5_col5" class="data row5 col5" >385</td>
#       <td id="T_7ce66_row5_col6" class="data row5 col6" >459</td>
#       <td id="T_7ce66_row5_col7" class="data row5 col7" >356</td>
#       <td id="T_7ce66_row5_col8" class="data row5 col8" >306</td>
#       <td id="T_7ce66_row5_col9" class="data ro

# %% [markdown]
# - O fundo amarelo quando movimentamos o mouse pode ser útil durante uma apresentação para facilitar que outras pessoas vejam a informação que você quer mostrar.

# %% [markdown]
# # Título

# %%
s = unique_tickets_by_week_and_hour.style

# table style
cell_hover = { # for row hover use <tr> instead of <td>
    'selector': 'td:hover',
    'props': [('background-color', '#ffffb3')]
}
index_names = {
    'selector': '.index_name',
    'props': 'font-style: italic; color: darkgrey; font-weight:normal;'
}
headers = {
    'selector': 'th:not(.index_name)',
    'props': 'background-color: #000076; color: white;'
}

s.set_table_styles([cell_hover, index_names, headers])

# title
s.set_caption("Count Invoices")\
 .set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: upper; font-size:2.25em; font-weight:bold'
 }],overwrite=False)
# Out:
# <style type="text/css">
# #T_803da_ td:hover {
#   background-color: #ffffb3;
# }
# #T_803da_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_803da_ th:not(.index_name) {
#   background-color: #000076;
#   color: white;
# }
# #T_803da_ caption {
#   caption-side: upper;
#   font-size: 2.25em;
#   font-weight: bold;
# }
# </style>
# <table id="T_803da_" class="dataframe">
#   <caption>Count Invoices</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Hour</th>
#       <th class="col_heading level0 col0" >6</th>
#       <th class="col_heading level0 col1" >7</th>
#       <th class="col_heading level0 col2" >8</th>
#       <th class="col_heading level0 col3" >9</th>
#       <th class="col_heading level0 col4" >10</th>
#       <th class="col_heading level0 col5" >11</th>
#       <th class="col_heading level0 col6" >12</th>
#       <th class="col_heading level0 col7" >13</th>
#       <th class="col_heading level0 col8" >14</th>
#       <th class="col_heading level0 col9" >15</th>
#       <th class="col_heading level0 col10" >16</th>
#       <th class="col_heading level0 col11" >17</th>
#       <th class="col_heading level0 col12" >18</th>
#       <th class="col_heading level0 col13" >19</th>
#       <th class="col_heading level0 col14" >20</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DayOfWeek</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_803da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_803da_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_803da_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_803da_row0_col2" class="data row0 col2" >85</td>
#       <td id="T_803da_row0_col3" class="data row0 col3" >251</td>
#       <td id="T_803da_row0_col4" class="data row0 col4" >322</td>
#       <td id="T_803da_row0_col5" class="data row0 col5" >340</td>
#       <td id="T_803da_row0_col6" class="data row0 col6" >480</td>
#       <td id="T_803da_row0_col7" class="data row0 col7" >436</td>
#       <td id="T_803da_row0_col8" class="data row0 col8" >374</td>
#       <td id="T_803da_row0_col9" class="data row0 col9" >317</td>
#       <td id="T_803da_row0_col10" class="data row0 col10" >184</td>
#       <td id="T_803da_row0_col11" class="data row0 col11" >70</td>
#       <td id="T_803da_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_803da_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_803da_row0_col14" class="data row0 col14" >0</td>
#     </tr>
#     <tr>
#       <th id="T_803da_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_803da_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_803da_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_803da_row1_col2" class="data row1 col2" >115</td>
#       <td id="T_803da_row1_col3" class="data row1 col3" >290</td>
#       <td id="T_803da_row1_col4" class="data row1 col4" >393</td>
#       <td id="T_803da_row1_col5" class="data row1 col5" >405</td>
#       <td id="T_803da_row1_col6" class="data row1 col6" >531</td>
#       <td id="T_803da_row1_col7" class="data row1 col7" >475</td>
#       <td id="T_803da_row1_col8" class="data row1 col8" >371</td>
#       <td id="T_803da_row1_col9" class="data row1 col9" >345</td>
#       <td id="T_803da_row1_col10" class="data row1 col10" >163</td>
#       <td id="T_803da_row1_col11" class="data row1 col11" >88</td>
#       <td id="T_803da_row1_col12" class="data row1 col12" >3</td>
#       <td id="T_803da_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_803da_row1_col14" class="data row1 col14" >0</td>
#     </tr>
#     <tr>
#       <th id="T_803da_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_803da_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_803da_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_803da_row2_col2" class="data row2 col2" >116</td>
#       <td id="T_803da_row2_col3" class="data row2 col3" >290</td>
#       <td id="T_803da_row2_col4" class="data row2 col4" >434</td>
#       <td id="T_803da_row2_col5" class="data row2 col5" >413</td>
#       <td id="T_803da_row2_col6" class="data row2 col6" >611</td>
#       <td id="T_803da_row2_col7" class="data row2 col7" >493</td>
#       <td id="T_803da_row2_col8" class="data row2 col8" >417</td>
#       <td id="T_803da_row2_col9" class="data row2 col9" >371</td>
#       <td id="T_803da_row2_col10" class="data row2 col10" >223</td>
#       <td id="T_803da_row2_col11" class="data row2 col11" >79</td>
#       <td id="T_803da_row2_col12" class="data row2 col12" >0</td>
#       <td id="T_803da_row2_col13" class="data row2 col13" >2</td>
#       <td id="T_803da_row2_col14" class="data row2 col14" >1</td>
#     </tr>
#     <tr>
#       <th id="T_803da_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_803da_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_803da_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_803da_row3_col2" class="data row3 col2" >119</td>
#       <td id="T_803da_row3_col3" class="data row3 col3" >294</td>
#       <td id="T_803da_row3_col4" class="data row3 col4" >442</td>
#       <td id="T_803da_row3_col5" class="data row3 col5" >370</td>
#       <td id="T_803da_row3_col6" class="data row3 col6" >586</td>
#       <td id="T_803da_row3_col7" class="data row3 col7" >479</td>
#       <td id="T_803da_row3_col8" class="data row3 col8" >445</td>
#       <td id="T_803da_row3_col9" class="data row3 col9" >421</td>
#       <td id="T_803da_row3_col10" class="data row3 col10" >309</td>
#       <td id="T_803da_row3_col11" class="data row3 col11" >245</td>
#       <td id="T_803da_row3_col12" class="data row3 col12" >164</td>
#       <td id="T_803da_row3_col13" class="data row3 col13" >133</td>
#       <td id="T_803da_row3_col14" class="data row3 col14" >16</td>
#     </tr>
#     <tr>
#       <th id="T_803da_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_803da_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_803da_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_803da_row4_col2" class="data row4 col2" >120</td>
#       <td id="T_803da_row4_col3" class="data row4 col3" >266</td>
#       <td id="T_803da_row4_col4" class="data row4 col4" >410</td>
#       <td id="T_803da_row4_col5" class="data row4 col5" >364</td>
#       <td id="T_803da_row4_col6" class="data row4 col6" >463</td>
#       <td id="T_803da_row4_col7" class="data row4 col7" >397</td>
#       <td id="T_803da_row4_col8" class="data row4 col8" >361</td>
#       <td id="T_803da_row4_col9" class="data row4 col9" >253</td>
#       <td id="T_803da_row4_col10" class="data row4 col10" >115</td>
#       <td id="T_803da_row4_col11" class="data row4 col11" >62</td>
#       <td id="T_803da_row4_col12" class="data row4 col12" >2</td>
#       <td id="T_803da_row4_col13" class="data row4 col13" >9</td>
#       <td id="T_803da_row4_col14" class="data row4 col14" >1</td>
#     </tr>
#     <tr>
#       <th id="T_803da_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_803da_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_803da_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_803da_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_803da_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_803da_row5_col4" class="data row5 col4" >225</td>
#       <td id="T_803da_row5_col5" class="data row5 col5" >385</td>
#       <td id="T_803da_row5_col6" class="data row5 col6" >459</td>
#       <td id="T_803da_row5_col7" class="data row5 col7"

# %% [markdown]
# # Destacando valores iguais a zero

# %%
s = unique_tickets_by_week_and_hour.style

# table style
cell_hover = { # for row hover use <tr> instead of <td>
    'selector': 'td:hover',
    'props': [('background-color', '#ffffb3')]
}
index_names = {
    'selector': '.index_name',
    'props': 'font-style: italic; color: darkgrey; font-weight:normal;'
}
headers = {
    'selector': 'th:not(.index_name)',
    'props': 'background-color: #000076; color: white;'
}

s.set_table_styles([cell_hover, index_names, headers])

# title
s.set_caption("Count Invoices")\
 .set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: upper; font-size:2.25em; font-weight:bold'
 }],overwrite=False)

# style zero
def style_zero(v, props=''):
    return props if v == 0 else None
s.applymap(style_zero, props='color:red;')
# Out:
# <style type="text/css">
# #T_324db_ td:hover {
#   background-color: #ffffb3;
# }
# #T_324db_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_324db_ th:not(.index_name) {
#   background-color: #000076;
#   color: white;
# }
# #T_324db_ caption {
#   caption-side: upper;
#   font-size: 2.25em;
#   font-weight: bold;
# }
# #T_324db_row0_col0, #T_324db_row0_col12, #T_324db_row0_col13, #T_324db_row0_col14, #T_324db_row1_col0, #T_324db_row1_col13, #T_324db_row1_col14, #T_324db_row2_col0, #T_324db_row2_col12, #T_324db_row4_col0, #T_324db_row5_col0, #T_324db_row5_col1, #T_324db_row5_col2, #T_324db_row5_col11, #T_324db_row5_col12, #T_324db_row5_col13, #T_324db_row5_col14 {
#   color: red;
# }
# </style>
# <table id="T_324db_" class="dataframe">
#   <caption>Count Invoices</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Hour</th>
#       <th class="col_heading level0 col0" >6</th>
#       <th class="col_heading level0 col1" >7</th>
#       <th class="col_heading level0 col2" >8</th>
#       <th class="col_heading level0 col3" >9</th>
#       <th class="col_heading level0 col4" >10</th>
#       <th class="col_heading level0 col5" >11</th>
#       <th class="col_heading level0 col6" >12</th>
#       <th class="col_heading level0 col7" >13</th>
#       <th class="col_heading level0 col8" >14</th>
#       <th class="col_heading level0 col9" >15</th>
#       <th class="col_heading level0 col10" >16</th>
#       <th class="col_heading level0 col11" >17</th>
#       <th class="col_heading level0 col12" >18</th>
#       <th class="col_heading level0 col13" >19</th>
#       <th class="col_heading level0 col14" >20</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DayOfWeek</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_324db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_324db_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_324db_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_324db_row0_col2" class="data row0 col2" >85</td>
#       <td id="T_324db_row0_col3" class="data row0 col3" >251</td>
#       <td id="T_324db_row0_col4" class="data row0 col4" >322</td>
#       <td id="T_324db_row0_col5" class="data row0 col5" >340</td>
#       <td id="T_324db_row0_col6" class="data row0 col6" >480</td>
#       <td id="T_324db_row0_col7" class="data row0 col7" >436</td>
#       <td id="T_324db_row0_col8" class="data row0 col8" >374</td>
#       <td id="T_324db_row0_col9" class="data row0 col9" >317</td>
#       <td id="T_324db_row0_col10" class="data row0 col10" >184</td>
#       <td id="T_324db_row0_col11" class="data row0 col11" >70</td>
#       <td id="T_324db_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_324db_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_324db_row0_col14" class="data row0 col14" >0</td>
#     </tr>
#     <tr>
#       <th id="T_324db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_324db_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_324db_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_324db_row1_col2" class="data row1 col2" >115</td>
#       <td id="T_324db_row1_col3" class="data row1 col3" >290</td>
#       <td id="T_324db_row1_col4" class="data row1 col4" >393</td>
#       <td id="T_324db_row1_col5" class="data row1 col5" >405</td>
#       <td id="T_324db_row1_col6" class="data row1 col6" >531</td>
#       <td id="T_324db_row1_col7" class="data row1 col7" >475</td>
#       <td id="T_324db_row1_col8" class="data row1 col8" >371</td>
#       <td id="T_324db_row1_col9" class="data row1 col9" >345</td>
#       <td id="T_324db_row1_col10" class="data row1 col10" >163</td>
#       <td id="T_324db_row1_col11" class="data row1 col11" >88</td>
#       <td id="T_324db_row1_col12" class="data row1 col12" >3</td>
#       <td id="T_324db_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_324db_row1_col14" class="data row1 col14" >0</td>
#     </tr>
#     <tr>
#       <th id="T_324db_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_324db_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_324db_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_324db_row2_col2" class="data row2 col2" >116</td>
#       <td id="T_324db_row2_col3" class="data row2 col3" >290</td>
#       <td id="T_324db_row2_col4" class="data row2 col4" >434</td>
#       <td id="T_324db_row2_col5" class="data row2 col5" >413</td>
#       <td id="T_324db_row2_col6" class="data row2 col6" >611</td>
#       <td id="T_324db_row2_col7" class="data row2 col7" >493</td>
#       <td id="T_324db_row2_col8" class="data row2 col8" >417</td>
#       <td id="T_324db_row2_col9" class="data row2 col9" >371</td>
#       <td id="T_324db_row2_col10" class="data row2 col10" >223</td>
#       <td id="T_324db_row2_col11" class="data row2 col11" >79</td>
#       <td id="T_324db_row2_col12" class="data row2 col12" >0</td>
#       <td id="T_324db_row2_col13" class="data row2 col13" >2</td>
#       <td id="T_324db_row2_col14" class="data row2 col14" >1</td>
#     </tr>
#     <tr>
#       <th id="T_324db_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_324db_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_324db_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_324db_row3_col2" class="data row3 col2" >119</td>
#       <td id="T_324db_row3_col3" class="data row3 col3" >294</td>
#       <td id="T_324db_row3_col4" class="data row3 col4" >442</td>
#       <td id="T_324db_row3_col5" class="data row3 col5" >370</td>
#       <td id="T_324db_row3_col6" class="data row3 col6" >586</td>
#       <td id="T_324db_row3_col7" class="data row3 col7" >479</td>
#       <td id="T_324db_row3_col8" class="data row3 col8" >445</td>
#       <td id="T_324db_row3_col9" class="data row3 col9" >421</td>
#       <td id="T_324db_row3_col10" class="data row3 col10" >309</td>
#       <td id="T_324db_row3_col11" class="data row3 col11" >245</td>
#       <td id="T_324db_row3_col12" class="data row3 col12" >164</td>
#       <td id="T_324db_row3_col13" class="data row3 col13" >133</td>
#       <td id="T_324db_row3_col14" class="data row3 col14" >16</td>
#     </tr>
#     <tr>
#       <th id="T_324db_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_324db_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_324db_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_324db_row4_col2" class="data row4 col2" >120</td>
#       <td id="T_324db_row4_col3" class="data row4 col3" >266</td>
#       <td id="T_324db_row4_col4" class="data row4 col4" >410</td>
#       <td id="T_324db_row4_col5" class="data row4 col5" >364</td>
#       <td id="T_324db_row4_col6" class="data row4 col6" >463</td>
#       <td id="T_324db_row4_col7" class="data row4 col7" >397</td>
#       <td id="T_324db_row4_col8" class="data row4 col8" >361</td>
#       <td id="T_324db_row4_col9" class="data row4 col9" >253</td>
#       <td id="T_324db_row4_col10" class="data row4 col10" >115</td>
#       <td id="T_324db_row4_col11" class="data row4 col11" >62</td>
#       <td id="T_324db_row4_col12" class="data row4 col12" >2</td>
#       <td id="T_324db_row4_col13" class="data row4 col13" >9</td>
#       <td id="T_324db_row4_col14" class="data row4 col14" >1</td>
#     </tr>
#     <tr>
#       <th id="T_324db_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_324db_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_324db_row5_col1" class="data row5 col1" >0</td>
#       <td id="T

# %% [markdown]
# - Aqui podemos ver dia e horários em que não ocorreram vendas
# - No lugar de mostrar os zeros em vermelho também poderiamos mostrar em vermelho valores menor que um mímino estabelecido.

# %% [markdown]
# # Destacando os valores maiores que 500 e deixando os demais mais claros

# %%
s = unique_tickets_by_week_and_hour.style

# table style
cell_hover = { # for row hover use <tr> instead of <td>
    'selector': 'td:hover',
    'props': [('background-color', '#ffffb3')]
}
index_names = {
    'selector': '.index_name',
    'props': 'font-style: italic; color: darkgrey; font-weight:normal;'
}
headers = {
    'selector': 'th:not(.index_name)',
    'props': 'background-color: #000076; color: white;'
}

s.set_table_styles([cell_hover, index_names, headers])

# title
s.set_caption("Count Invoices")\
 .set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: upper; font-size:2.25em; font-weight:bold'
 }],overwrite=False)

# style zero
def style_zero(v, props=''):
    return props if v == 0 else None
s.applymap(style_zero, props='color:red;')

# unique_tickets_by_week_and_hour
s.applymap(lambda v: 'opacity: 20%;' if (v < 500) else None)
# Out:
# <style type="text/css">
# #T_8efdd_ td:hover {
#   background-color: #ffffb3;
# }
# #T_8efdd_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_8efdd_ th:not(.index_name) {
#   background-color: #000076;
#   color: white;
# }
# #T_8efdd_ caption {
#   caption-side: upper;
#   font-size: 2.25em;
#   font-weight: bold;
# }
# #T
row4_col12" class="data row4 col12" >2</td>
#       <td id="T_35bda_row4_col13" class="data row4 col13" >9</td>
#       <td id="T_35bda_row4_col14" class="data row4 col14" >1</td>
#     </tr>
#     <tr>
#       <th id="T_35bda_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_35bda_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_35bda_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_35bda_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_35bda_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_35bda_row5_col4" class="data row5 col4" >225</td>
#       <td id="T_35bda_row5_col5" class="data row5 col5" >385</td>
#       <td id="T_35bda_row5_col6" class="data row5 col6" >459</td>

# %% [markdown]
# - Quarta (dia 2) as 12 horas é o dia com o maior número de vendas.

# %% [markdown]
# # Tabela com margens - total da linha e total da coluna

# %%
unique_tickets_by_week_and_hour = pd.pivot_table(n_tickets_by_week_and_hour, 
                                          index = 'DayOfWeek',
                                          columns = 'Hour', 
                                          values = 'InvoiceNo',
                                          fill_value=0,
                                          margins=True, 
                                          margins_name='All',
                                          aggfunc='sum'
                                          )

unique_tickets_by_week_and_hour
# Out:
# Hour       6   7    8     9    10    11  ...    16   17   18   19  20    All
# DayOfWeek                                ...
# 0          0   4   85   251   322   340  ...   184   70    0    0   0   2863
# 1          0   5  115   290   393   405  ...   163   88    3    0   0   3184
# 2          0   5  116   290   434   413  ...   223   79    0    2   1   3455
# 3          1   9  119   294   442   370  ...   309  245  164  133  16   4033
# 4          0   6  120   266   410   364  ...   115   62    2    9   1   2829
# 6          0   0    0     2   225   385  ...   106    0    0    0   0   2169
# All        1  29  555  1393  2226  2277  ...  1100  544  169  144  18  18533
#
# [7 rows x 16 columns]

# %%
s = unique_tickets_by_week_and_hour.style

# table style
cell_hover = { # for row hover use <tr> instead of <td>
    'selector': 'td:hover',
    'props': [('background-color', '#ffffb3')]
}
index_names = {
    'selector': '.index_name',
    'props': 'font-style: italic; color: darkgrey; font-weight:normal;'
}
headers = {
    'selector': 'th:not(.index_name)',
    'props': 'background-color: #000076; color: white;'
}

s.set_table_styles([cell_hover, index_names, headers])

# title
s.set_caption("Count Invoices")\
 .set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: upper; font-size:2.25em; font-weight:bold'
 }],overwrite=False)


# backgroud column All
slice_ = ['All']
s.set_properties(**{'background-color': 'lightblue'}, subset=slice_)

# backgroud row All
idx = pd.IndexSlice
slice_ = idx['All',:]
s.set_properties(**{'background-color': 'lightblue'}, subset=slice_)


# vertical line
s.set_table_styles({
    ('All'): [{'selector': 'th', 'props': 'border-left: 1px solid white'},
                               {'selector': 'td', 'props': 'border-left: 1px solid #000066'}]
}, overwrite=False, axis=0)


# horizontal line
s.set_table_styles({
    ('All'): [{'selector': '', 'props': 'border-top: 1px solid white'},
                               {'selector': 'td', 'props': 'border-top: 1px solid #000066'}]
}, overwrite=False, axis=1)
# Out:
# <style type="text/css">
# #T_53777_ td:hover {
#   background-color: #ffffb3;
# }
# #T_53777_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_53777_ th:not(.index_name) {
#   background-color: #000076;
#   color: white;
# }
# #T_53777_ caption {
#   caption-side: upper;
#   font-size: 2.25em;
#   font-weight: bold;
# }
# #T_53777_ th.col15 {
#   border-left: 1px solid white;
# }
# #T_53777_ td.col15 {
#   border-left: 1px solid #000066;
# }
# #T_53777_ .row6 {
#   border-top: 1px solid white;
# }
# #T_53777_ td.row6 {
#   border-top: 1px solid #000066;
# }
# #T_53777_row0_col15, #T_53777_row1_col15, #T_53777_row2_col15, #T_53777_row3_col15, #T_53777_row4_col15, #T_53777_row5_col15, #T_53777_row6_col0, #T_53777_row6_col1, #T_53777_row6_col2, #T_53777_row6_col3, #T_53777_row6_col4, #T_53777_row6_col5, #T_53777_row6_col6, #T_53777_row6_col7, #T_53777_row6_col8, #T_53777_row6_col9, #T_53777_row6_col10, #T_53777_row6_col11, #T_53777_row6_col12, #T_53777_row6_col13, #T_53777_row6_col14 {
#   background-color: lightblue;
# }
# #T_53777_row6_col15 {
#   background-color: lightblue;
#   background-color: lightblue;
# }
# </style>
# <table id="T_53777_" class="dataframe">
#   <caption>Count Invoices</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Hour</th>
#       <th class="col_heading level0 col0" >6</th>
#       <th class="col_heading level0 col1" >7</th>
#       <th class="col_heading level0 col2" >8</th>
#       <th class="col_heading level0 col3" >9</th>
#       <th class="col_heading level0 col4" >10</th>
#       <th class="col_heading level0 col5" >11</th>
#       <th class="col_heading level0 col6" >12</th>
#       <th class="col_heading level0 col7" >13</th>
#       <th class="col_heading level0 col8" >14</th>
#       <th class="col_heading level0 col9" >15</th>
#       <th class="col_heading level0 col10" >16</th>
#       <th class="col_heading level0 col11" >17</th>
#       <th class="col_heading level0 col12" >18</th>
#       <th class="col_heading level0 col13" >19</th>
#       <th class="col_heading level0 col14" >20</th>
#       <th class="col_heading level0 col15" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DayOfWeek</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53777_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_53777_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_53777_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_53777_row0_col2" class="data row0 col2" >85</td>
#       <td id="T_53777_row0_col3" class="data row0 col3" >251</td>
#       <td id="T_53777_row0_col4" class="data row0 col4" >322</td>
#       <td id="T_53777_row0_col5" class="data row0 col5" >340</td>
#       <td id="T_53777_row0_col6" class="data row0 col6" >480</td>
#       <td id="T_53777_row0_col7" class="data row0 col7" >436</td>
#       <td id="T_53777_row0_col8" class="data row0 col8" >374</td>
#       <td id="T_53777_row0_col9" class="data row0 col9" >317</td>
#       <td id="T_53777_row0_col10" class="data row0 col10" >184</td>
#       <td id="T_53777_row0_col11" class="data row0 col11" >70</td>
#       <td id="T_53777_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_53777_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_53777_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_53777_row0_col15" class="data row0 col15" >2863</td>
#     </tr>
#     <tr>
#       <th id="T_53777_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_53777_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_53777_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_53777_row1_col2" class="data row1 col2" >115</td>
#       <td id="T_53777_row1_col3" class="data row1 col3" >290</td>
#       <td id="T_53777_row1_col4" class="data row1 col4" >393</td>
#       <td id="T_53777_row1_col5" class="data row1 col5" >405</td>
#       <td id="T_53777_row1_col6" class="data row1 col6" >531</td>
#       <td id="T_53777_row1_col7" class="data row1 col7" >475</td>
#       <td id="T_53777_row1_col8" class="data row1 col8" >371</td>
#       <td id="T_53777_row1_col9" class="data row1 col9" >345</td>
#       <td id="T_53777_row1_col10" class="data row1 col10" >163</td>
#       <td id="T_53777_row1_col11" class="data row1 col11" >88</td>
#       <td id="T_53777_row1_col12" class="data row1 col12" >3</td>
#       <td id="T_53777_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_53777_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_53777_row1_col15" class="data row1 col15" >3184</td>
#     </tr>
#     <tr>
#       <th id="T_53777_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_53777_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_53777_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_53777_row2_col2" class="data row2 col2" >116</td>
#       <td id="T_53777_row2_col3" class="data row2 col3" >290</td>
#       <td id="T_53777_row2_col4" class="data row2 col4" >434</td>
#       <td id="T_53777_row2_col5" class="data row2 col5" >413</td>
#       <td id="T_53777_row2_col6" class="data row2 col6" >611</td>
#       <td id="T_53777_row2_col7" class="data row2 col7" >493</td>
#       <td id="T_53777_row2_col8" class="data row2 col8" >417</td>
#       <td id="T_53777_row2_col9" class="data row2 col9" >371</td>
#       <td id="T_53777_row2_col10" class="data row2 col10" >223</td>
#       <td id="T_53777_row2_col11" class="data row2 col11" >79</td>
#       <td id="T_53777_row2_col12" class="data row2 col12" >0</td>
#       <td id="T_53777_row2_col13" class="data row2 col13" >2</td>
#       <td id="T_53777_row2_col14" class="data row2 col14" >1</td>
#       <td id="T_53777_row2_col15" class="data row2 col15" >3455</td>
#     </tr>
#     <tr>
#       <th id="T_53777_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_53777_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_53777_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_53777_row3_col2" class="data row3 col2" >119</td>
#       <td id="T_53777_row3_col3" class="data row3 col3" >294</td>
#       <td id="T_53777_row3_col4" class="data row3 col4" >442</td>
#       <td id="T_53777_row3_col5" class="data row3 col5" >370</td>
#       <td id="T_53777_row3_col6" class="data row3 col6" >586</td>
#       <td id="T_53777_row3_col7" class="data row3 col7" >479</td>
#       <td id="T_53777_row3_col8" class="data row3 col8" >445</td>
#       <td id="T_53777_row3_col9" class="data row3 col9" >421</td>
#       <td id="T_53777_row3_col10" class="data row3 col10" >309</td>
#       <td id="T_53777_row3_col11" class="data row3 col11" >245</td>
#       <td id="T_53777_row3_col12" class="data row3 col12" >164</td>
#       <td id="T_53777_row3_col13" class="data row3 col13" >133</td>
#       <td id="T_53777_row3_col14" class="data row3 col14" >16</td>
#       <td id="T_53777_row3_col15" class="data row3 col15" >4033</td>
#     </tr>
#     <tr>
#       <th id="T_53777_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_53777_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_53777_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_53777_row4_col2" class="data row4 col2" >120</td>
#       <td id="T_53777_row4_col3" class="data row4 col3" >266</td>
#       <td id="T_53777_row4_col4" class="data row4 col4" >410</td>
#       <td id="T_53777_row4_col5" class="data row4 col5" >364</td>
#       <td id="T_53777_row4_col6" class="data row4 col6" >463

# %% [markdown]
# - Muito melhor ver os resultados agora.

# %% [markdown]
# # Máximo entre as soma das linhas (dias da semana)

# %%
s = unique_tickets_by_week_and_hour.style

# table style
cell_hover = { # for row hover use <tr> instead of <td>
    'selector': 'td:hover',
    'props': [('background-color', '#ffffb3')]
}
index_names = {
    'selector': '.index_name',
    'props': 'font-style: italic; color: darkgrey; font-weight:normal;'
}
headers = {
    'selector': 'th:not(.index_name)',
    'props': 'background-color: #000076; color: white;'
}

s.set_table_styles([cell_hover, index_names, headers])

# title
s.set_caption("Count Invoices")\
 .set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: upper; font-size:2.25em; font-weight:bold'
 }],overwrite=False)


# backgroud column All
slice_ = ['All']
s.set_properties(**{'background-color': 'lightblue'}, subset=slice_)

# backgroud row All
idx = pd.IndexSlice
slice_ = idx['All',:]
s.set_properties(**{'background-color': 'lightblue'}, subset=slice_)


# vertical line
s.set_table_styles({
    ('All'): [{'selector': 'th', 'props': 'border-left: 1px solid white'},
                               {'selector': 'td', 'props': 'border-left: 1px solid #000066'}]
}, overwrite=False, axis=0)


# horizontal line
s.set_table_styles({
    ('All'): [{'selector': '', 'props': 'border-top: 1px solid white'},
                               {'selector': 'td', 'props': 'border-top: 1px solid #000066'}]
}, overwrite=False, axis=1)

# highlight max in row All

idx = pd.IndexSlice
slice_ = idx[idx[0:6], idx['All']]

s.highlight_max(color='lightgreen', axis = 0, subset=slice_)
# Out:
# <style type="text/css">
# #T_7f75c_ td:hover {
#   background-color: #ffffb3;
# }
# #T_7f75c_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_7f75c_ th:not(.index_name) {
#   background-color: #000076;
#   color: white;
# }
# #T_7f75c_ caption {
#   caption-side: upper;
#   font-size: 2.25em;
#   font-weight: bold;
# }
# #T_7f75c_ th.col15 {
#   border-left: 1px solid white;
# }
# #T_7f75c_ td.col15 {
#   border-left: 1px solid #000066;
# }
# #T_7f75c_ .row6 {
#   border-top: 1px solid white;
# }
# #T_7f75c_ td.row6 {
#   border-top: 1px solid #000066;
# }
# #T_7f75c_row0_col15, #T_7f75c_row1_col15, #T_7f75c_row2_col15, #T_7f75c_row4_col15, #T_7f75c_row5_col15, #T_7f75c_row6_col0, #T_7f75c_row6_col1, #T_7f75c_row6_col2, #T_7f75c_row6_col3, #T_7f75c_row6_col4, #T_7f75c_row6_col5, #T_7f75c_row6_col6, #T_7f75c_row6_col7, #T_7f75c_row6_col8, #T_7f75c_row6_col9, #T_7f75c_row6_col10, #T_7f75c_row6_col11, #T_7f75c_row6_col12, #T_7f75c_row6_col13, #T_7f75c_row6_col14 {
#   background-color: lightblue;
# }
# #T_7f75c_row3_col15 {
#   background-color: lightblue;
#   background-color: lightgreen;
# }
# #T_7f75c_row6_col15 {
#   background-color: lightblue;
#   background-color: lightblue;
# }
# </style>
# <table id="T_7f75c_" class="dataframe">
#   <caption>Count Invoices</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Hour</th>
#       <th class="col_heading level0 col0" >6</th>
#       <th class="col_heading level0 col1" >7</th>
#       <th class="col_heading level0 col2" >8</th>
#       <th class="col_heading level0 col3" >9</th>
#       <th class="col_heading level0 col4" >10</th>
#       <th class="col_heading level0 col5" >11</th>
#       <th class="col_heading level0 col6" >12</th>
#       <th class="col_heading level0 col7" >13</th>
#       <th class="col_heading level0 col8" >14</th>
#       <th class="col_heading level0 col9" >15</th>
#       <th class="col_heading level0 col10" >16</th>
#       <th class="col_heading level0 col11" >17</th>
#       <th class="col_heading level0 col12" >18</th>
#       <th class="col_heading level0 col13" >19</th>
#       <th class="col_heading level0 col14" >20</th>
#       <th class="col_heading level0 col15" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DayOfWeek</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f75c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f75c_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_7f75c_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_7f75c_row0_col2" class="data row0 col2" >85</td>
#       <td id="T_7f75c_row0_col3" class="data row0 col3" >251</td>
#       <td id="T_7f75c_row0_col4" class="data row0 col4" >322</td>
#       <td id="T_7f75c_row0_col5" class="data row0 col5" >340</td>
#       <td id="T_7f75c_row0_col6" class="data row0 col6" >480</td>
#       <td id="T_7f75c_row0_col7" class="data row0 col7" >436</td>
#       <td id="T_7f75c_row0_col8" class="data row0 col8" >374</td>
#       <td id="T_7f75c_row0_col9" class="data row0 col9" >317</td>
#       <td id="T_7f75c_row0_col10" class="data row0 col10" >184</td>
#       <td id="T_7f75c_row0_col11" class="data row0 col11" >70</td>
#       <td id="T_7f75c_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_7f75c_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_7f75c_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_7f75c_row0_col15" class="data row0 col15" >2863</td>
#     </tr>
#     <tr>
#       <th id="T_7f75c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7f75c_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_7f75c_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_7f75c_row1_col2" class="data row1 col2" >115</td>
#       <td id="T_7f75c_row1_col3" class="data row1 col3" >290</td>
#       <td id="T_7f75c_row1_col4" class="data row1 col4" >393</td>
#       <td id="T_7f75c_row1_col5" class="data row1 col5" >405</td>
#       <td id="T_7f75c_row1_col6" class="data row1 col6" >531</td>
#       <td id="T_7f75c_row1_col7" class="data row1 col7" >475</td>
#       <td id="T_7f75c_row1_col8" class="data row1 col8" >371</td>
#       <td id="T_7f75c_row1_col9" class="data row1 col9" >345</td>
#       <td id="T_7f75c_row1_col10" class="data row1 col10" >163</td>
#       <td id="T_7f75c_row1_col11" class="data row1 col11" >88</td>
#       <td id="T_7f75c_row1_col12" class="data row1 col12" >3</td>
#       <td id="T_7f75c_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_7f75c_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_7f75c_row1_col15" class="data row1 col15" >3184</td>
#     </tr>
#     <tr>
#       <th id="T_7f75c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7f75c_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_7f75c_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_7f75c_row2_col2" class="data row2 col2" >116</td>
#       <td id="T_7f75c_row2_col3" class="data row2 col3" >290</td>
#       <td id="T_7f75c_row2_col4" class="data row2 col4" >434</td>
#       <td id="T_7f75c_row2_col5" class="data row2 col5" >413</td>
#       <td id="T_7f75c_row2_col6" class="data row2 col6" >611</td>
#       <td id="T_7f75c_row2_col7" class="data row2 col7" >493</td>
#       <td id="T_7f75c_row2_col8" class="data row2 col8" >417</td>
#       <td id="T_7f75c_row2_col9" class="data row2 col9" >371</td>
#       <td id="T_7f75c_row2_col10" class="data row2 col10" >223</td>
#       <td id="T_7f75c_row2_col11" class="data row2 col11" >79</td>
#       <td id="T_7f75c_row2_col12" class="data row2 col12" >0</td>
#       <td id="T_7f75c_row2_col13" class="data row2 col13" >2</td>
#       <td id="T_7f75c_row2_col14" class="data row2 col14" >1</td>
#       <td id="T_7f75c_row2_col15" class="data row2 col15" >3455</td>
#     </tr>
#     <tr>
#       <th id="T_7f75c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7f75c_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_7f75c_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_7f75c_row3_col2" class="data row3 col2" >119</td>
#       <td id="T_7f75c_row3_col3" class="data row3 col3" >294</td>
#       <td id="T_7f75c_row3_col4" class="data row3 col4" >442</td>
#       <td id="T_7f75c_row3_col5" class="data row3 col5" >370</td>
#       <td id="T_7f75c_row3_col6" class="data row3 col6" >586</td>
#       <td id="T_7f75c_row3_col7" class="data row3 col7" >479</td>
#       <td id="T_7f75c_row3_col8" class="data row3 col8" >445</td>
#       <td id="T_7f75c_row3_col9" class="data row3 col9" >421</td>
#       <td id="T_7f75c_row3_col10" class="data row3 col10" >309</td>
#       <td id="T_7f75c_row3_col11" class="data row3 col11" >245</td>
#       <td id="T_7f75c_row3_col12" class="data row3 col12" >164</td>
#       <td id="T_7f75c_row3_col13" class="data row3 col13" >133</td>
#       <td id="T_7f75c_row3_col14" class="data row3 col14" >16</td>
#       <td id="T_7f75c_row3_col15" class="data row3 col15" >4033</td>
#     </tr>
#     <tr>
#       <th id="T_7f75c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7f75c_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_7f75c_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_7f75c_row4_col2" class="data row4 col2" >120</td>
#       <td id="T_7f75c_row4_col3" class="data row4 col3" >266</td>
#       <td id="T_7f75c_row4_col4" class="data row4 col4" >410</td>
#       <td id="T_7f75c_row4_col5" class="data row4 col5" >364

# %% [markdown]
# - Dia 3 (quinta) é o dia com mais vendas.

# %% [markdown]
# # Mínimo entre as soma das colunas (dias da semana)

# %%
s = unique_tickets_by_week_and_hour.style

# table style
cell_hover = { # for row hover use <tr> instead of <td>
    'selector': 'td:hover',
    'props': [('background-color', '#ffffb3')]
}
index_names = {
    'selector': '.index_name',
    'props': 'font-style: italic; color: darkgrey; font-weight:normal;'
}
headers = {
    'selector': 'th:not(.index_name)',
    'props': 'background-color: #000076; color: white;'
}

s.set_table_styles([cell_hover, index_names, headers])

# title
s.set_caption("Count Invoices")\
 .set_table_styles([{
     'selector': 'caption',
     'props': 'caption-side: upper; font-size:2.25em; font-weight:bold'
 }],overwrite=False)


# backgroud column All
slice_ = ['All']
s.set_properties(**{'background-color': 'lightblue'}, subset=slice_)

# backgroud row All
idx = pd.IndexSlice
slice_ = idx['All',:]
s.set_properties(**{'background-color': 'lightblue'}, subset=slice_)


# vertical line
s.set_table_styles({
    ('All'): [{'selector': 'th', 'props': 'border-left: 1px solid white'},
                               {'selector': 'td', 'props': 'border-left: 1px solid #000066'}]
}, overwrite=False, axis=0)


# horizontal line
s.set_table_styles({
    ('All'): [{'selector': '', 'props': 'border-top: 1px solid white'},
                               {'selector': 'td', 'props': 'border-top: 1px solid #000066'}]
}, overwrite=False, axis=1)

# highlight max in row All

idx = pd.IndexSlice
slice_ = idx[idx['All'], idx[6:20]] # [6:20] = name of first column: name of last column

s.highlight_min(color='#FF7F7F', axis = 1, subset=slice_)
# Out:
# <style type="text/css">
# #T_ec723_ td:hover {
#   background-color: #ffffb3;
# }
# #T_ec723_ .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_ec723_ th:not(.index_name) {
#   background-color: #000076;
#   color: white;
# }
# #T_ec723_ caption {
#   caption-side: upper;
#   font-size: 2.25em;
#   font-weight: bold;
# }
# #T_ec723_ th.col15 {
#   border-left: 1px solid white;
# }
# #T_ec723_ td.col15 {
#   border-left: 1px solid #000066;
# }
# #T_ec723_ .row6 {
#   border-top: 1px solid white;
# }
# #T_ec723_ td.row6 {
#   border-top: 1px solid #000066;
# }
# #T_ec723_row0_col15, #T_ec723_row1_col15, #T_ec723_row2_col15, #T_ec723_row3_col15, #T_ec723_row4_col15, #T_ec723_row5_col15, #T_ec723_row6_col1, #T_ec723_row6_col2, #T_ec723_row6_col3, #T_ec723_row6_col4, #T_ec723_row6_col5, #T_ec723_row6_col6, #T_ec723_row6_col7, #T_ec723_row6_col8, #T_ec723_row6_col9, #T_ec723_row6_col10, #T_ec723_row6_col11, #T_ec723_row6_col12, #T_ec723_row6_col13, #T_ec723_row6_col14 {
#   background-color: lightblue;
# }
# #T_ec723_row6_col0 {
#   background-color: lightblue;
#   background-color: #FF7F7F;
# }
# #T_ec723_row6_col15 {
#   background-color: lightblue;
#   background-color: lightblue;
# }
# </style>
# <table id="T_ec723_" class="dataframe">
#   <caption>Count Invoices</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Hour</th>
#       <th class="col_heading level0 col0" >6</th>
#       <th class="col_heading level0 col1" >7</th>
#       <th class="col_heading level0 col2" >8</th>
#       <th class="col_heading level0 col3" >9</th>
#       <th class="col_heading level0 col4" >10</th>
#       <th class="col_heading level0 col5" >11</th>
#       <th class="col_heading level0 col6" >12</th>
#       <th class="col_heading level0 col7" >13</th>
#       <th class="col_heading level0 col8" >14</th>
#       <th class="col_heading level0 col9" >15</th>
#       <th class="col_heading level0 col10" >16</th>
#       <th class="col_heading level0 col11" >17</th>
#       <th class="col_heading level0 col12" >18</th>
#       <th class="col_heading level0 col13" >19</th>
#       <th class="col_heading level0 col14" >20</th>
#       <th class="col_heading level0 col15" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DayOfWeek</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec723_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec723_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ec723_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_ec723_row0_col2" class="data row0 col2" >85</td>
#       <td id="T_ec723_row0_col3" class="data row0 col3" >251</td>
#       <td id="T_ec723_row0_col4" class="data row0 col4" >322</td>
#       <td id="T_ec723_row0_col5" class="data row0 col5" >340</td>
#       <td id="T_ec723_row0_col6" class="data row0 col6" >480</td>
#       <td id="T_ec723_row0_col7" class="data row0 col7" >436</td>
#       <td id="T_ec723_row0_col8" class="data row0 col8" >374</td>
#       <td id="T_ec723_row0_col9" class="data row0 col9" >317</td>
#       <td id="T_ec723_row0_col10" class="data row0 col10" >184</td>
#       <td id="T_ec723_row0_col11" class="data row0 col11" >70</td>
#       <td id="T_ec723_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_ec723_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_ec723_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_ec723_row0_col15" class="data row0 col15" >2863</td>
#     </tr>
#     <tr>
#       <th id="T_ec723_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ec723_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_ec723_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_ec723_row1_col2" class="data row1 col2" >115</td>
#       <td id="T_ec723_row1_col3" class="data row1 col3" >290</td>
#       <td id="T_ec723_row1_col4" class="data row1 col4" >393</td>
#       <td id="T_ec723_row1_col5" class="data row1 col5" >405</td>
#       <td id="T_ec723_row1_col6" class="data row1 col6" >531</td>
#       <td id="T_ec723_row1_col7" class="data row1 col7" >475</td>
#       <td id="T_ec723_row1_col8" class="data row1 col8" >371</td>
#       <td id="T_ec723_row1_col9" class="data row1 col9" >345</td>
#       <td id="T_ec723_row1_col10" class="data row1 col10" >163</td>
#       <td id="T_ec723_row1_col11" class="data row1 col11" >88</td>
#       <td id="T_ec723_row1_col12" class="data row1 col12" >3</td>
#       <td id="T_ec723_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_ec723_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_ec723_row1_col15" class="data row1 col15" >3184</td>
#     </tr>
#     <tr>
#       <th id="T_ec723_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ec723_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_ec723_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_ec723_row2_col2" class="data row2 col2" >116</td>
#       <td id="T_ec723_row2_col3" class="data row2 col3" >290</td>
#       <td id="T_ec723_row2_col4" class="data row2 col4" >434</td>
#       <td id="T_ec723_row2_col5" class="data row2 col5" >413</td>
#       <td id="T_ec723_row2_col6" class="data row2 col6" >611</td>
#       <td id="T_ec723_row2_col7" class="data row2 col7" >493</td>
#       <td id="T_ec723_row2_col8" class="data row2 col8" >417</td>
#       <td id="T_ec723_row2_col9" class="data row2 col9" >371</td>
#       <td id="T_ec723_row2_col10" class="data row2 col10" >223</td>
#       <td id="T_ec723_row2_col11" class="data row2 col11" >79</td>
#       <td id="T_ec723_row2_col12" class="data row2 col12" >0</td>
#       <td id="T_ec723_row2_col13" class="data row2 col13" >2</td>
#       <td id="T_ec723_row2_col14" class="data row2 col14" >1</td>
#       <td id="T_ec723_row2_col15" class="data row2 col15" >3455</td>
#     </tr>
#     <tr>
#       <th id="T_ec723_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ec723_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_ec723_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_ec723_row3_col2" class="data row3 col2" >119</td>
#       <td id="T_ec723_row3_col3" class="data row3 col3" >294</td>
#       <td id="T_ec723_row3_col4" class="data row3 col4" >442</td>
#       <td id="T_ec723_row3_col5" class="data row3 col5" >370</td>
#       <td id="T_ec723_row3_col6" class="data row3 col6" >586</td>
#       <td id="T_ec723_row3_col7" class="data row3 col7" >479</td>
#       <td id="T_ec723_row3_col8" class="data row3 col8" >445</td>
#       <td id="T_ec723_row3_col9" class="data row3 col9" >421</td>
#       <td id="T_ec723_row3_col10" class="data row3 col10" >309</td>
#       <td id="T_ec723_row3_col11" class="data row3 col11" >245</td>
#       <td id="T_ec723_row3_col12" class="data row3 col12" >164</td>
#       <td id="T_ec723_row3_col13" class="data row3 col13" >133</td>
#       <td id="T_ec723_row3_col14" class="data row3 col14" >16</td>
#       <td id="T_ec723_row3_col15" class="data row3 col15" >4033</td>
#     </tr>
#     <tr>
#       <th id="T_ec723_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ec723_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_ec723_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_ec723_row4_col2" class="data row4 col2" >120</td>
#       <td id="T_ec723_row4_col3" class="data row4 col3" >266</td>
#       <td id="T_ec723_row4_col4" class="data row4 col4" >410</td>
#       <td id="T_ec723_row4_col5" class="data row4 col5" >364</t

# %% [markdown]
# - O pior horário é 6 horas.

# %% [markdown]
# # Observações
#
# - Não há dados para o dia 5, sábado. É algo que podia ser investigado.
#
# - Teria ficado mais fácil analisar se tivesse colocado o nome dos dias da semana
#
# - Poderia ampliar a análise considerando os valores das compras, o número de clientes

# %% [markdown]
# # Conclusão
#
# Utilitilizando Pandas, groupby, pivot_table e style podemos extrair informações importantes dos dados de forma clara e muito fácil de visualizar.
